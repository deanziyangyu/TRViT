# %% [markdown]
# ### Environment Setup and Downloads

# %%
# install openmim from pip
# !pip install torchmetrics
# !pip install -U openmim
# !mim install mmengine
# !mim install mmcv
# !mim install mmdet
# !mim install mmpose
# !mim install mmaction

# %%
# clone repo
# !git clone https://github.com/open-mmlab/mmaction2.git
# !pip install -v -e ./mmaction2

# %%
# create dirs
# !mkdir checkpoints
# !mkdir data

# %%
# download model
# !mim download mmaction2 --config stgcn_8xb16-bone-u100-80e_ntu60-xsub-keypoint-3d --dest .

# %%
# download matching dataset pkl
# !wget https://download.openmmlab.com/mmaction/v1.0/skeleton/data/ntu60_3d.pkl ./data/skeleton

# %% [markdown]
# ### Model Running

# %% [markdown]
# Training the Model (Single GPU)

# %%
# On other machines change python3.7 to `python` or `python3` to match your enviroment
# !python3.7 mmaction2/tools/train.py mmaction2/configs/skeleton/stgcn/stgcn_8xb16-bone-u100-80e_ntu60-xsub-keypoint-3d.py --amp

# %% [markdown]
# Training the Model (Multi-GPU)

# %%
# !bash mmaction2/tools/dist_train.sh mmaction2/configs/skeleton/stgcn/stgcn_8xb16-bone-u100-80e_kimore-xsub-keypoint-3d.py\
 3 --amp
# Out:
# + CONFIG=mmaction2/configs/skeleton/stgcn/stgcn_8xb16-bone-u100-80e_kimore-xsub-keypoint-3d.py
# + GPUS=3
# + NNODES=1
# + NODE_RANK=0
# + PORT=29500
# + MASTER_ADDR=127.0.0.1
# ++ dirname mmaction2/tools/dist_train.sh
# ++ dirname mmaction2/tools/dist_train.sh
# + PYTHONPATH=mmaction2/tools/..:
# + python3.7 -m torch.distributed.launch --nnodes=1 --node_rank=0 --master_addr=127.0.0.1 --nproc_per_node=3 --master_port=29500 mmaction2/tools/train.py mmaction2/configs/skeleton/stgcn/stgcn_8xb16-bone-u100-80e_kimore-xsub-keypoint-3d.py --launcher pytorch --amp
# /home/yipgroup/.local/lib/python3.7/site-packages/torch/distributed/launch.py:188: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# Traceback (most recent call last):
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 855, in _file2dict
#     with tempfile.TemporaryDirectory() as temp_config_dir:
#   File "/usr/lib/python3.7/tempfile.py", line 929, in __init__
#     self.name = mkdtemp(suffix, prefix, dir)
#   File "/usr/lib/python3.7/tempfile.py", line 502, in mkdtemp
#     name = next(names)
#   File "/usr/lib/python3.7/tempfile.py", line 295, in __next__
#     letters = [choose(c) for dummy in range(8)]
#   File "/usr/lib/python3.7/tempfile.py", line 295, in <listcomp>
#     letters = [choose(c) for dummy in range(8)]
#   File "/usr/lib/python3.7/random.py", line 259, in choice
#     i = self._randbelow(len(seq))
#   File "/usr/lib/python3.7/random.py", line 232, in _randbelow
#     if type(random) is BuiltinMethod or type(getrandbits) is Method:
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
# ...
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 941, in _file2dict
#     raise e
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 887, in _file2dict
#     lazy_import=lazy_import,
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/mmengine/config/config.py", line 939, in _file2dict
#     if osp.exists(temp_config_dir):
# UnboundLocalError: local variable 'temp_config_dir' referenced before assignment
# ERROR:torch.distributed.elastic.multiprocessing.api:failed (exitcode: 1) local_rank: 0 (pid: 17938) of binary: /usr/bin/python3.7
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/torch/distributed/launch.py", line 195, in <module>
#     main()
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/torch/distributed/launch.py", line 191, in main
#     launch(args)
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/torch/distributed/launch.py", line 176, in launch
#     run(args)
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/torch/distributed/run.py", line 756, in run
#     )(*cmd_args)
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/torch/distributed/launcher/api.py", line 132, in __call__
#     return launch_agent(self._config, self._entrypoint, list(args))
#   File "/home/yipgroup/.local/lib/python3.7/site-packages/torch/distributed/launcher/api.py", line 248, in launch_agent
#     failures=result.failures,
# torch.distributed.elastic.multiprocessing.errors.ChildFailedError:
# ============================================================
# mmaction2/tools/train.py FAILED
# ------------------------------------------------------------
# Failures:
# [1]:
#   time      : 2023-11-08_16:59:15
#   host      : yipgroup-hsw-3090
#   rank      : 1 (local_rank: 1)
#   exitcode  : 1 (pid: 17939)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# [2]:
#   time      : 2023-11-08_16:59:15
#   host      : yipgroup-hsw-3090
#   rank      : 2 (local_rank: 2)
#   exitcode  : 1 (pid: 17940)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# ------------------------------------------------------------
# Root Cause (first observed failure):
# [0]:
#   time      : 2023-11-08_16:59:15
#   host      : yipgroup-hsw-3090
#   rank      : 0 (local_rank: 0)
#   exitcode  : 1 (pid: 17938)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# ============================================================

# %% [markdown]
# Testing the Pretrained Model Here:

# %%
# On other machines change python3.7 to `python` or `python3` to match your enviroment
# !python3.7 mmaction2/tools/test.py mmaction2/configs/skeleton/stgcn/stgcn_8xb16-bone-u100-80e_ntu60-xsub-keypoint-3d.py \
    /home/yipgroup/Documents/01_projects/TRViT/src/nb/work_dirs/stgcn_8xb16-bone-u100-80e_ntu60-xsub-keypoint-3d/epoch_16.pth --dump result.pkl

# %% [markdown]
# ### Convert Results to CSV

# %%
import pickle as pkl
import pandas as pd
with open("result.pkl", "rb") as f:
    object = pkl.load(f)
    
df = pd.DataFrame(object)
df.to_csv(r'result.csv')
