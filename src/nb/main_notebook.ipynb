# %% [markdown]
# ### Environment Setup and Downloads

# %%
# install openmim from pip
# !pip install torch==2.1.0+cu121 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install torchmetrics
# !pip install -U openmim
# !mim install mmengine
# !mim install mmcv
# !mim install mmdet
# !mim install mmpose
# !mim install mmaction
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 GB 968.2 kB/s eta 0:00:000:0100:05
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 10.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 10.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 11.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 7.9 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 KB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.0/154.0 KB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 10.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 10.7 MB/s eta 0:00:0000:0100:01
# ...

# %%
# clone repo
# !git clone https://github.com/open-mmlab/mmaction2.git
# !pip install -v -e ./mmaction2
# Out:
# fatal: destination path 'mmaction2' already exists and is not an empty directory.
# Using pip 22.0.2 from /home/yipgroup/Documents/01_Projects/TRViT/mm2_venv/lib/python3.10/site-packages/pip (python 3.10)
# Obtaining file:///home/yipgroup/Documents/01_Projects/TRViT/src/nb/mmaction2
#   Preparing metadata (setup.py) ...   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-cnsuh4fg/mmaction2.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-cnsuh4fg/mmaction2.egg-info/SOURCES.txt'
# ...
#   writing manifest file '/tmp/pip-pip-egg-info-cnsuh4fg/mmaction2.egg-info/SOURCES.txt'
# done
# ...
#   Using cached decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
# ...
#   Using cached einops-0.7.0-py3-none-any.whl (44 kB)
# ...
#   Using cached opencv_contrib_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67.8 MB)
# ...
#   Running setup.py develop for mmaction2
#     Running command python setup.py develop
#     running develop
# ...

# %%
# create dirs
# !mkdir checkpoints
# !mkdir data

# %%
# download model
# !mim download mmaction2 --config stgcn_8xb16-bone-u100-80e_ntu60-xsub-keypoint-3d --dest .

# %%
# download matching dataset pkl
# !wget https://download.openmmlab.com/mmaction/v1.0/skeleton/data/ntu60_3d.pkl ./data/skeleton

# %% [markdown]
# ### Model Running

# %% [markdown]
# Training the Model (Single GPU)

# %%
# On other machines change python3.7 to `python` or `python3` to match your enviroment
# !python3 mmaction2/tools/train.py mmaction2/configs/skeleton/stgcn/stgcn_8xb16-bone-u100-80e_ntu60-xsub-keypoint-3d.py --amp

# %% [markdown]
# Training the Model (Multi-GPU)

# %%
# !bash mmaction2/tools/dist_train.sh mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold0.py\
 3 --amp
# Out:
# + CONFIG=mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold0.py
# + GPUS=3
# + NNODES=1
# + NODE_RANK=0
# + PORT=29500
# + MASTER_ADDR=127.0.0.1
# ++ dirname mmaction2/tools/dist_train.sh
# ++ dirname mmaction2/tools/dist_train.sh
# + PYTHONPATH=mmaction2/tools/..:
# + python3.7 -m torch.distributed.launch --nnodes=1 --node_rank=0 --master_addr=127.0.0.1 --nproc_per_node=3 --master_port=29500 mmaction2/tools/train.py mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold0.py --launcher pytorch --amp
# /home/yipgroup/.local/lib/python3.7/site-packages/torch/distributed/launch.py:188: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# ...

# %%
# !bash mmaction2/tools/dist_train.sh mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold1.py\
 3 --amp
# !bash mmaction2/tools/dist_train.sh mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold2.py\
 3 --amp
# !bash mmaction2/tools/dist_train.sh mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold3.py\
 3 --amp
# !bash mmaction2/tools/dist_train.sh mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold4.py\
 3 --amp
# !bash mmaction2/tools/dist_train.sh mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold5.py\
 3 --amp
# !bash mmaction2/tools/dist_train.sh mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold6.py\
 3 --amp
# !bash mmaction2/tools/dist_train.sh mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold7.py\
 3 --amp
# !bash mmaction2/tools/dist_train.sh mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold8.py\
 3 --amp
# !bash mmaction2/tools/dist_train.sh mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold9.py\
 3 --amp
# Out:
# + CONFIG=mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold1.py
# + GPUS=3
# + NNODES=1
# + NODE_RANK=0
# + PORT=29500
# + MASTER_ADDR=127.0.0.1
# ++ dirname mmaction2/tools/dist_train.sh
# ++ dirname mmaction2/tools/dist_train.sh
# + PYTHONPATH=mmaction2/tools/..:
# + python3.7 -m torch.distributed.launch --nnodes=1 --node_rank=0 --master_addr=127.0.0.1 --nproc_per_node=3 --master_port=29500 mmaction2/tools/train.py mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold1.py --launcher pytorch --amp
# /home/yipgroup/.local/lib/python3.7/site-packages/torch/distributed/launch.py:188: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# ...

# %%
# !bash mmaction2/tools/dist_train.sh \
mmaction2/configs/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-fold0.py \
3 --amp

# %%
# !CUDA_VISIBLE_DEVICES=1,2 bash mmaction2/tools/dist_train.sh \
mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-lmso-fold0.py \
2 --amp

# !CUDA_VISIBLE_DEVICES=1,2 bash mmaction2/tools/dist_train.sh \
# mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-lmso-fold1.py \
# 2 --amp

# !CUDA_VISIBLE_DEVICES=1,2 bash mmaction2/tools/dist_train.sh \
# mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-lmso-fold2.py \
# 2 --amp

# !CUDA_VISIBLE_DEVICES=1,2 bash mmaction2/tools/dist_train.sh \
# mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-lmso-fold3.py \
# 2 --amp
# Out:
# + CONFIG=mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-lmso-fold0.py
# + GPUS=2
# + NNODES=1
# + NODE_RANK=0
# + PORT=29500
# + MASTER_ADDR=127.0.0.1
# ++ dirname mmaction2/tools/dist_train.sh
# ++ dirname mmaction2/tools/dist_train.sh
# + PYTHONPATH=mmaction2/tools/..:
# + python3.7 -m torch.distributed.launch --nnodes=1 --node_rank=0 --master_addr=127.0.0.1 --nproc_per_node=2 --master_port=29500 mmaction2/tools/train.py mmaction2/configs/skeleton/stgcnpp/stgcnpp_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-lmso-fold0.py --launcher pytorch --amp
# /home/yipgroup/.local/lib/python3.7/site-packages/torch/distributed/launch.py:188: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# ...

# %%
# !CUDA_VISIBLE_DEVICES=1,2 bash mmaction2/tools/dist_train.sh \
mmaction2/configs/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-lmso-fold0.py \
2 --amp

# !CUDA_VISIBLE_DEVICES=1,2 bash mmaction2/tools/dist_train.sh \
mmaction2/configs/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-lmso-fold1.py \
2 --amp

# !CUDA_VISIBLE_DEVICES=1,2 bash mmaction2/tools/dist_train.sh \
mmaction2/configs/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-lmso-fold2.py \
2 --amp

# !CUDA_VISIBLE_DEVICES=1,2 bash mmaction2/tools/dist_train.sh \
mmaction2/configs/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d-lmso-fold3.py \
2 --amp

# %% [markdown]
# Testing the Pretrained Model Here:

# %%
# On other machines change python3.7 to `python` or `python3` to match your enviroment
# !python3.7 mmaction2/tools/test.py mmaction2/configs/skeleton/stgcn/stgcn_8xb16-bone-u100-80e_ntu60-xsub-keypoint-3d.py \
    /home/yipgroup/Documents/01_projects/TRViT/src/nb/work_dirs/stgcn_8xb16-bone-u100-80e_ntu60-xsub-keypoint-3d/epoch_16.pth --dump result.pkl

# %% [markdown]
# ### Convert Results to CSV

# %%
import pickle as pkl
import pandas as pd
with open("result.pkl", "rb") as f:
    object = pkl.load(f)
    
df = pd.DataFrame(object)
df.to_csv(r'result.csv')
